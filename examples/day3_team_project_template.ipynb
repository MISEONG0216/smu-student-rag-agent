# %% [markdown]
# # **3일차 팀 프로젝트: 테이블 데이터 조회 시스템 구축**
#
# ## 프로젝트 목표
# 1. 팀에서 선정한 CSV 테이블 데이터를 Supabase에 적재
# 2. SQL 쿼리로 데이터 조회 테스트
# 3. Text2SQL 시스템 구현 및 테스트
#
# ## 구현 단계
# - 환경 설정 확인
# - CSV 파일 확인 및 탐색
# - Supabase 연결
# - CSV 데이터 업로드
# - SQL 쿼리 테스트
# - Text2SQL 시스템 구현 및 테스트

# %% [markdown]
# ## 0. 환경 변수 설정

# %%
import os
from dotenv import load_dotenv

load_dotenv()

# OpenAI API Key 확인
if os.environ.get("OPENAI_API_KEY"):
    print("✓ OpenAI API Key가 설정되었습니다.")
else:
    print("✗ OpenAI API Key가 없습니다.")

# Supabase 설정 확인
if os.environ.get("SUPABASE_DB_URL"):
    print("✓ Supabase DB URL이 설정되었습니다.")
else:
    print("✗ Supabase DB URL이 필요합니다.")
    print("  .env 파일에 SUPABASE_DB_URL을 추가하세요.")
# Out:
# ✓ OpenAI API Key가 설정되었습니다.
# ✓ Supabase DB URL이 설정되었습니다.

# %% [markdown]
# ## 1. CSV 파일 확인 및 탐색
#
# **TODO: 팀에서 준비한 CSV 파일 경로를 입력하세요**
#
# **중요:** 여러 CSV 파일을 사용하는 경우, 테이블 간 관계(Foreign Key)를 고려하여 업로드 순서를 결정하세요.
# - 부모 테이블 → 자식 테이블 순서로 업로드

# %%
import pandas as pd

# TODO: 팀의 CSV 파일 경로를 입력하세요
# 여러 파일이 있다면 dict 형태로 구성
# 예시:
# csv_files = {
#     "table1": "../datasets/your_table1.csv",
#     "table2": "../datasets/your_table2.csv"
# }

csv_files = {
    "SMU_2026_2": r"C:\Users\USER\Desktop\smu0818\smu-ai-service-bootcamp\rag-system\datasets\2026-2학기_개설학과별_시간표_2026.8.19._기준.csv"
    # 필요한 만큼 추가
}

# CSV 파일 로드 및 확인
dataframes = {}

for table_name, file_path in csv_files.items():
    try:
        df = pd.read_csv(file_path)
        dataframes[table_name] = df

        print("=" * 80)
        print(f"📋 {table_name} 테이블")
        print("=" * 80)
        print(f"\n행 수: {len(df)}")
        print(f"컬럼: {list(df.columns)}")
        print(f"\n첫 5개 행:")
        print(df.head())
        print(f"\n데이터 타입:")
        print(df.dtypes)
        print("\n")

    except Exception as e:
        print(f"✗ {table_name} 로드 실패: {e}\n")

print(f"\n✓ 총 {len(dataframes)}개의 테이블 로드 완료")
# Out:
# ================================================================================
# 📋 SMU_2026_2 테이블
# ================================================================================
#
# 행 수: 1152
# 컬럼: ['No', '학년', '이수구분', '학수번호', '교과목명', '학점', '이론시간', '실습시간', '교양영역', '강의시간(강의실)', '분반', '담당교수', '비고']
#
# 첫 5개 행:
#    No 학년 이수구분      학수번호               교과목명  학점  이론시간  실습시간 교양영역     강의시간(강의실)  \
# 0   1  3  1전선  HBCD0001  취업과창업(글로벌인문학부대학 )   1   1.0   0.0  NaN     토11(Y102)
# 1   1  1  1전선  HBHI0004          글로벌시대의인문학   2   2.0   0.0  NaN    목2,3(E106)
# 2   2  1  1전선  HBHI0004          글로벌시대의인문학   2   2.0   0.0  NaN    목2,3(E503)
# 3   3  1  1전선  HBHI0004          글로벌시대의인문학   2   2.0   0.0  NaN    목2,3(E402)
# 4   1  1  1전선  HBHA1011            한국어학의이해   3   3.0   0.0  NaN  수1,2,3(E502)
#
#   분반     담당교수                               비고
# 0  1      유진현                              NaN
# 1  1  박주은,양동국  글로벌지역학부 1,6 분반만 신청, 이중설강제 선정교과목
# 2  2  윤태희,정의진  글로벌지역학부 2,3 분반만 신청, 이중설강제 선정교과목
# 3  3  박정희,최종술  글로벌지역학부 4,5 분반만 신청, 이중설강제 선정교과목
# 4  1      전정미                              NaN
#
# 데이터 타입:
# No             int64
# 학년               str
# 이수구분             str
# 학수번호             str
# 교과목명             str
# 학점             int64
# 이론시간         float64
# 실습시간         float64
# 교양영역             str
# 강의시간(강의실)        str
# 분반               str
# 담당교수             str
# 비고               str
# dtype: object
#
#
#
# ✓ 총 1개의 테이블 로드 완료

# %% [markdown]
# ## 2. 데이터 탐색 및 통계
#
# **TODO: 팀 데이터에 맞는 탐색 쿼리를 작성하세요**

# %%
# TODO: 각 테이블의 주요 통계를 확인하세요
# 예시:
# - 특정 컬럼의 고유값 개수
# - 카테고리별 데이터 분포
# - 결측치 확인

for table_name, df in dataframes.items():
    print(f"\n{'='*80}")
    print(f"📊 {table_name} 통계")
    print("="*80)

    # 기본 통계
    print("\n[기본 정보]")
    print(df.info())

    # 결측치 확인
    print("\n[결측치]")
    null_counts = df.isnull().sum()
    if null_counts.sum() > 0:
        print(null_counts[null_counts > 0])
    else:
        print("결측치 없음")

    # TODO: 팀 데이터에 맞는 추가 탐색 코드를 작성하세요
    # 예시:
    # print("\n[카테고리 분포]")
    # print(df['YOUR_COLUMN'].value_counts())
# Out:
# ================================================================================
# 📊 SMU_2026_2 통계
# ================================================================================
#
# [기본 정보]
# <class 'pandas.DataFrame'>
# RangeIndex: 1152 entries, 0 to 1151
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   No         1152 non-null   int64
#  1   학년         1152 non-null   str
#  2   이수구분       1152 non-null   str
#  3   학수번호       1152 non-null   str
#  4   교과목명       1152 non-null   str
#  5   학점         1152 non-null   int64
#  6   이론시간       1152 non-null   float64
#  7   실습시간       1152 non-null   float64
#  8   교양영역       150 non-null    str
#  9   강의시간(강의실)  1146 non-null   str
#  10  분반         1146 non-null   str
#  11  담당교수       1146 non-null   str
#  12  비고         533 non-null    str
# dtypes: float64(2), int64(2), str(9)
# memory usage: 230.3 KB
# None
#
# [결측치]
# 교양영역         1002
# 강의시간(강의실)       6
# 분반              6
# 담당교수            6
# 비고            619
# dtype: int64

# %% [markdown]
# ## 3. Supabase PostgreSQL 연결

# %%
from langchain_community.utilities import SQLDatabase

supabase_db_url = os.getenv("SUPABASE_DB_URL")

if not supabase_db_url:
    raise Exception("SUPABASE_DB_URL이 설정되지 않았습니다. .env 파일을 확인하세요.")

print("Supabase PostgreSQL 연결 중...\n")

try:
    # LangChain SQLDatabase로 PostgreSQL 연결
    db = SQLDatabase.from_uri(supabase_db_url)

    print("✓ PostgreSQL 연결 성공!\n")
    print("현재 테이블 목록:")
    tables = db.get_usable_table_names()
    print(tables)

except Exception as e:
    print(f"✗ 연결 실패: {e}")
    raise
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_7716\1442992373.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.utilities import SQLDatabase
# Supabase PostgreSQL 연결 중...
#
# ✓ PostgreSQL 연결 성공!
#
# 현재 테이블 목록:
# ['SMU_2026_2', 'departments', 'office_floors', 'organizations']

# %% [markdown]
# ## 4. Supabase에 CSV 데이터 업로드
#
# ### Supabase 대시보드 (GUI)
# 1. Supabase 대시보드 접속
# 2. Table Editor → Import data from CSV
# 3. **반드시 테이블 관계 순서대로 업로드** (부모 → 자식)
# 4. Foreign Key 에러 발생 시 순서를 재확인

# %% [markdown]
# ## 5. 업로드 확인 및 스키마 탐색

# %%
# 데이터베이스 다시 연결 (업로드 후 스키마 갱신)
db = SQLDatabase.from_uri(supabase_db_url)

print("=== 데이터베이스 스키마 ===")
print(db.table_info)

print("\n" + "="*80 + "\n")

# 각 테이블의 샘플 데이터
for table in db.get_usable_table_names():
    print(f"{table} 테이블 샘플:")
    try:
        result = db.run(f"SELECT * FROM {table} LIMIT 3")
        print(result)
    except Exception as e:
        print(f"조회 실패: {e}")
    print()
# Out:
# === 데이터베이스 스키마 ===
#
# CREATE TABLE "SMU_2026_2" (
# 	"No" BIGINT,
# 	"학년" TEXT,
# 	"이수구분" TEXT,
# 	"학수번호" TEXT,
# 	"교과목명" TEXT,
# 	"학점" BIGINT,
# 	"이론시간" DOUBLE PRECISION,
# 	"실습시간" DOUBLE PRECISION,
# 	"교양영역" TEXT,
# 	"강의시간(강의실)" TEXT,
# 	"분반" TEXT,
# 	"담당교수" TEXT,
# 	"비고" TEXT
# )
#
# /*
# 3 rows from SMU_2026_2 table:
# No	학년	이수구분	학수번호	교과목명	학점	이론시간	실습시간	교양영역	강의시간(강의실)	분반	담당교수	비고
# 1	3	1전선	HBCD0001	취업과창업(글로벌인문학부대학 )	1	1.0	0.0	None	토11(Y102)	1	유진현	nan
# 1	1	1전선	HBHI0004	글로벌시대의인문학	2	2.0	0.0	None	목2,3(E106)	1	박주은,양동국	글로벌지역학부 1,6 분반만 신청, 이중설강제 선정교과목
# 2	1	1전선	HBHI0004	글로벌시대의인문학	2	2.0	0.0	None	목2,3(E503)	2	윤태희,정의진	글로벌지역학부 2,3 분반만 신청, 이중설강제 선정교과목
# */
#
#
# CREATE TABLE departments (
# 	dept_id BIGINT,
# 	dept_name TEXT,
# 	org_id BIGINT,
# 	dept_code TEXT,
# 	phone TEXT,
# 	fax TEXT,
# 	floor_location TEXT,
# 	description TEXT
# )
#
# /*
# 3 rows from departments table:
# dept_id	dept_name	org_id	dept_code	phone	fax	floor_location	description
# 101	홍보담당관	2	D101	041-521-2080	041-521-2089	본관 8층	홍보업무 총괄 및 보도자료 관리
# 102	감사관	2	D102	041-521-2040	041-521-2049	본관 4층	감사업무 총괄 및 청렴윤리 관리
# 103	스마트도시추진과	2	D103	041-521-2205	041-521-2209	본관 7층	스마트도시 정책 및 AI산업 추진
# */
#
#
# CREATE TABLE office_floors (
# 	floor_id BIGINT,
# 	building_name TEXT,
# 	floor_number BIGINT,
# 	floor_name TEXT,
# 	main_departments TEXT,
# 	facilities TEXT,
# 	area_type TEXT
# )
#
# /*
# 3 rows from office_floors table:
# floor_id	building_name	floor_number	floor_name	main_departments	facilities	area_type
# 1	천안시청 본관	1	본관 1층	민원여권과,노인복지과,허가과,복지정책과,장애인복지과,청년정책과	청사카페,민원실,대기공간	민원서비스층
# 2	천안시청 본관	2	본관 2층	미래전략과,일자리경제과,교육청소년과,청소행정과,K-컬처박람회추진과	도솔도서관	행정문화층
# 3	천안시청 본관	3	본관 3층	여성가족과,아동보육과	콜센터,대회의실,천안시정공무원노동조합	복지행정층
# */
#
#
# CREATE TABLE organizations (
# 	org_id BIGINT,
# 	org_name TEXT,
# 	org_type TEXT,
# 	parent_org_id BIGINT,
# 	org_level BIGINT,
# 	org_code TEXT,
# 	description TEXT
# )
#
# /*
# 3 rows from organizations table:
# org_id	org_name	org_type	parent_org_id	org_level	org_code	description
# 1	천안시청	시청	None	1	CA001	천안시 본청
# 2	부시장 직속	직속	1	2	CA002	부시장 직속 부서
# 3	기획조정실	실	1	2	CA003	정책 기획 및 예산 총괄
# */
#
# ================================================================================
#
# SMU_2026_2 테이블 샘플:
# 조회 실패: (psycopg2.errors.UndefinedTable) relation "smu_2026_2" does not exist
# LINE 1: SELECT * FROM SMU_2026_2 LIMIT 3
#                       ^
#
# [SQL: SELECT * FROM SMU_2026_2 LIMIT 3]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#
# departments 테이블 샘플:
# [(101, '홍보담당관', 2, 'D101', '041-521-2080', '041-521-2089', '본관 8층', '홍보업무 총괄 및 보도자료 관리'), (102, '감사관', 2, 'D102', '041-521-2040', '041-521-2049', '본관 4층', '감사업무 총괄 및 청렴윤리 관리'), (103, '스마트도시추진과', 2, 'D103', '041-521-2205', '041-521-2209', '본관 7층', '스마트도시 정책 및 AI산업 추진')]
#
# office_floors 테이블 샘플:
# [(1, '천안시청 본관', 1, '본관 1층', '민원여권과,노인복지과,허가과,복지정책과,장애인복지과,청년정책과', '청사카페,민원실,대기공간', '민원서비스층'), (2, '천안시청 본관', 2, '본관 2층', '미래전략과,일자리경제과,교육청소년과,청소행정과,K-컬처박람회추진과', '도솔도서관', '행정문화층'), (3, '천안시청 본관', 3, '본관 3층', '여성가족과,아동보육과', '콜센터,대회의실,천안시정공무원노동조합', '복지행정층')]
#
# organizations 테이블 샘플:
# [(1, '천안시청', '시청', None, 1, 'CA001', '천안시 본청'), (2, '부시장 직속', '직속', 1, 2, 'CA002', '부시장 직속 부서'), (3, '기획조정실', '실', 1, 2, 'CA003', '정책 기획 및 예산 총괄')]

# %% [markdown]
# ## 6. SQL 쿼리 테스트
#
# **TODO: 팀 데이터에 맞는 SQL 쿼리를 작성하여 테스트하세요**

# %%
# TODO: 조건부 조회 쿼리 작성 (학점이 3 이상인 과목)

query = """
SELECT "교과목명", "이수구분", "학점", "담당교수", "강의시간(강의실)"
FROM "SMU_2026_2"
WHERE "학점" >= 3
LIMIT 10;
"""

print("실행 쿼리:")
print(query)
print("\n결과:")

try:
    result = db.run(query)
    print(result)
except Exception as e:
    print(f"쿼리 실행 오류: {e}")
# Out:
# 실행 쿼리:
#
# SELECT "교과목명", "이수구분", "학점", "담당교수", "강의시간(강의실)"
# FROM "SMU_2026_2"
# WHERE "학점" >= 3
# LIMIT 10;
#
#
# 결과:
# [('한국어학의이해', '1전선', 3, '전정미', '수1,2,3(E502)'), ('한국현대시의이해', '1전선', 3, '김지윤', '수5,6,7(E502)'), ('한국현대소설의이해', '1전선', 3, '김한식', '월5,6,7(E502)'), ('한국고전서사와문화콘텐츠', '1전선', 3, '이희영', '수6,7,8(I110)'), ('한국어어휘교육론', '1전선', 3, '양영하,한정희', '수1,2,3(I109)'), ('AI 시대의 시 감상과 뉴미디어 표현', '1전심', 3, '김지윤', '목3,4,5(C301)'), ('한국어발음교육론', '1전선', 3, '한정희', '화5,6,7(E502)'), ('한국문학과세계문학', '1전선', 3, '김한식', '목1,2,3(I110)'), ('한국어한자교육론', '1전심', 3, '이희영', '목1,2,3(E502)'), ('한국어이해교육론', '1전심', 3, '전정미', '화1,2,3(E502)')]

# %%
# TODO: JOIN 쿼리 작성 (여러 테이블을 사용하는 경우)
# 예시: 두 테이블을 조인하여 데이터 조회

join_query = """
-- TODO: JOIN 쿼리를 작성하세요
-- 예시:
-- SELECT a.column1, b.column2
-- FROM table1 a
-- INNER JOIN table2 b ON a.id = b.foreign_id
-- LIMIT 10;
"""

print("실행 쿼리:")
print(join_query)
print("\n결과:")

try:
    result = db.run(join_query)
    print(result)
except Exception as e:
    print(f"쿼리 실행 오류: {e}")
# Out:
# 실행 쿼리:
#
# -- TODO: JOIN 쿼리를 작성하세요
# -- 예시:
# -- SELECT a.column1, b.column2
# -- FROM table1 a
# -- INNER JOIN table2 b ON a.id = b.foreign_id
# -- LIMIT 10;
#
#
# 결과:
# 쿼리 실행 오류: (psycopg2.ProgrammingError) can't execute an empty query
# [SQL:
# -- TODO: JOIN 쿼리를 작성하세요
# -- 예시:
# -- SELECT a.column1, b.column2
# -- FROM table1 a
# -- INNER JOIN table2 b ON a.id = b.foreign_id
# -- LIMIT 10;
# ]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# TODO: 집계(Aggregation) 쿼리 작성

aggregation_query = """
SELECT 
    "이수구분", 
    COUNT(*) AS "개설과목수", 
    SUM("학점") AS "총학점"
FROM "SMU_2026_2"
GROUP BY "이수구분"
ORDER BY "개설과목수" DESC;
"""

print("실행 쿼리:")
print(aggregation_query)
print("\n결과:")

try:
    result = db.run(aggregation_query)
    print(result)
except Exception as e:
    print(f"쿼리 실행 오류: {e}")
# Out:
# 실행 쿼리:
#
# SELECT
#     "이수구분",
#     COUNT(*) AS "개설과목수",
#     SUM("학점") AS "총학점"
# FROM "SMU_2026_2"
# GROUP BY "이수구분"
# ORDER BY "개설과목수" DESC;
#
#
# 결과:
# [('1전선', 643, Decimal('1819')), ('1전심', 254, Decimal('707')), ('교선', 183, Decimal('423')), ('교필', 65, Decimal('159')), ('1MD', 4, Decimal('12')), ('일선', 3, Decimal('8'))]

# %% [markdown]
# ## 7. Text2SQL 함수 구현
#
# **TODO: 시스템 프롬프트를 팀 데이터 도메인에 맞게 수정하세요**

# %%
from langchain.chat_models import init_chat_model
from langchain_core.messages import SystemMessage, HumanMessage

llm = init_chat_model("gpt-5.4-mini")

def text_to_sql(question: str, db: SQLDatabase) -> str:
    """
    자연어 질문을 SQL로 변환
    """
    # TODO: 시스템 프롬프트를 팀 데이터에 맞게 수정하세요
    system_prompt = f"""
    당신은 SQL 전문가입니다.
    사용자의 질문을 SQL 쿼리로 변환하세요.

    데이터베이스 스키마:
    {db.table_info}

    규칙:
    - PostgreSQL 문법 사용
    - SELECT 쿼리만 생성 (INSERT, UPDATE, DELETE 금지)
    - SQL 코드만 반환 (설명 불필요)
    - 코드 블록(```) 없이 순수 SQL만 반환
    - 세미콜론(;)으로 끝내기

    사용 가능한 SQL 문법:
    - JOIN (INNER, LEFT, RIGHT, FULL)
    - GROUP BY, HAVING
    - 집계 함수 (COUNT, SUM, AVG, MIN, MAX)
    - 서브쿼리
    - WHERE, ORDER BY, LIMIT
    - CTE (WITH 절)
    - 윈도우 함수
    """

    messages = [
        SystemMessage(content=system_prompt),
        HumanMessage(content=question)
    ]

    response = llm.invoke(messages)
    sql = response.content.strip()

    # 코드 블록 제거
    if sql.startswith("```"):
        lines = sql.split("\n")
        sql = "\n".join(lines[1:-1]) if len(lines) > 2 else sql
        sql = sql.replace("sql", "").replace("```", "").strip()

    return sql

print("✓ Text2SQL 함수 준비 완료")
# Out:
# ✓ Text2SQL 함수 준비 완료

# %% [markdown]
# ## 8. Text2SQL 테스트
#
# **TODO: 팀 데이터에 맞는 자연어 질문으로 테스트하세요**

# %%
# TODO: 팀 데이터에 맞는 질문을 작성하세요
question = "화요일 3학점 수업 알려줘."

print(f"질문: {question}\n")
print("="*80)

# SQL 생성
sql = text_to_sql(question, db)
print(f"\n생성된 SQL:")
print(sql)
print()

# SQL 실행
print("="*80)
print("\n실행 결과:")
try:
    result = db.run(sql)
    print(result)
except Exception as e:
    print(f"실행 오류: {e}")
# Out:
# 질문: 화요일 3학점 수업 알려줘.
#
# ================================================================================
#
# 생성된 SQL:
# SELECT "학수번호", "교과목명", "학점", "강의시간(강의실)", "담당교수", "분반"
# FROM "SMU_2026_2"
# WHERE "학점" = 3
#   AND "강의시간(강의실)" LIKE '화%'
# ORDER BY "교과목명";
#
# ================================================================================
#
# 실행 결과:
# [('HBIT0014', '3D 환경 디자인', 3, '화1,2,3(F305)', '김원재', '1'), ('HBIT0005', '3D모델링Ⅱ', 3, '화5,6,7(F305)', '김국토,김원재', '1'), ('HBIT0005', '3D모델링Ⅱ', 3, '화5,6,7(F305)', '김국토,김원재', '1'), ('HBIT0005', '3D모델링Ⅱ', 3, '화5,6,7(F305)', '김국토,김원재', '1'), ('HBIT0021', '3D영상제작Ⅱ', 3, '화1,2,3(F301)', '이상원,조혜정', '1'), ('HBIT0021', '3D영상제작Ⅱ', 3, '화1,2,3(F301)', '이상원,조혜정', '1'), ('HBKI0059', '3D컴퓨터그래픽스Ⅲ(SW)', 3, '화5,6,7(D422)', '이승엽', '2'), ('HBKJ0045', 'AI 콘텐츠기획&제작', 3, '화1,2,3(D412)', '설지형', '1'), ('HBEB0055', 'AI로봇어드벤처디자인', 3, '화6,7(I510) 화0(Z101)', '염기원', '1'), ('HBKI0048', 'AI미디어콘텐츠포트폴리오(캡스 톤디자인)', 3, '화1,2,3(I208)', '은광하', '1'), ('HBKI0048', 'AI미디어콘텐츠포트폴리오(캡스 톤디자인)', 3, '화6,7,8(D423)', '조일현', '2'), ('HBLF7826', 'AI시대의컬처리터러시', 3, '화1,2,3(I210)', '임혜원', '1'), ('HBKI0056', 'AI와예술', 3, '화1,2,3(D421)', '허영', '2'), ('HBKJ0043', 'AI표현기법워크샵', 3, '화8,9,10(D414)', '김서윤', '3'), ('HBMA1022', 'C프로그래밍및프로젝트(PBL)', 3, '화5,6,7(I409)', '김혜윤', '1'), ('HBLA5210', 'EnglishforAcademicPurposes', 3, '화1,2,3(I106)', '방민희', '8'), ('HBLA5210', 'EnglishforAcademicPurposes', 3, '화1,2,3(I104)', '박태숙', '9'), ('HBRO0064', 'IoT시스템응용', 3, '화1,2,3(N203)', '이광재', '1'), ('HBLB5080', 'K-culture를통해보는예술의산업 가치', 3, '화1,2,3(I307)', '강혜승', '1'), ('HBIE2132', 'Shop스페이스디자인Ⅰ(PBL)', 3, '화6,7,8(D327)', '명은정', '3'), ('HBIE2132', 'Shop스페이스디자인Ⅰ(PBL)', 3, '화6,7,8(D322)', '신라영', '2'), ('HBJN2109', 'VerilogHDL과디지털시스템설계', 3, '화1,2,3(C317)', '김선희', '1'), ('HBHE4370', 'ZD독일어', 3, '화6,7,8(E402)', '미정', '1'), ('HBIE3221', '가구와인간공학', 3, '화1,2,3(D327)', '명은정', '1'), ('HBAM0005', '객체지향프로그래밍', 3, '화7,8,9(N203)', '강태구', '1'), ('HBAM0005', '객체지향프로그래밍', 3, '화7,8,9(N203)', '강태구', '1'), ('HBMA1008', '객체지향프로그래밍(PBL)', 3, '화5,6,7(I805)', '김기봉', '2'), ('HBVE0002', '게임엔진2', 3, '화1,2,3(D422)', '공지훈', '1'), ('HBKJ0077', '게임제작과 컨셉아트', 3, '화1,2,3(D409)', '김치훈', '1'), ('HBJP2272', '경영통계Ⅱ', 3, '화5,6,7(I820)', '최성훈', '1'), ('HBJE3032', '경영프로젝트(캡스톤디자인)', 3, '화1,2,3(I105)', '이경희', '1'), ('HBJP2255', '경제성공학', 3, '화1,2,3(I801A)', '서광규', '2'), ('HBJP2255', '경제성공학', 3, '화1,2,3(I801A)', '서광규', '2'), ('HBMA1023', '계산과학이론및실습', 3, '화8,9,10(I404)', '정성균', '1'), ('HBMA1018', '고급 C프로그래밍', 3, '화4(I719) 수1,2(I719)', '박현주', '1'), ('HBSM0010', '고급 R 프로그래밍', 3, '화1,2,3(I805)', '김기봉', '1'), ('HBJO2231', '고성능컴퓨팅(PBL)', 3, '화1,2,3(I107)', '성광제', '1'), ('HBKE0063', '공연기획실습2(캡스톤디자인)', 3, '화5,6(S103) 목11(S103)', '최현주', '1'), ('HBKE0041', '공연예술경영론', 3, '화2,3,4(I109)', '최현주', '1'), ('HBJW0034', '공학수학Ⅱ(PBL)', 3, '화4,5,6(C407B)', '조준희', '2'), ('HBJE4355', '관리회계', 3, '화5,6,7(I111)', '오동일', '1'), ('HBHD4556', '국제사회와일본정치', 3, '화1,2,3(E205)', '양동국', '1'), ('HBOA1031', '그린스마트데이터솔루션 워크숍(캡스톤디자인)', 3, '화5,6,7(B306)', '조미경', '1'), ('HBIE4374', '기초실내디자인', 3, '화8,9,10(D325)', '하숙녕', '2'), ('HBIH4523', '기초연극워크숍Ⅱ', 3, '화2,3(S109) 금9(S109)', '윤기훈', '1'), ('HBEB0030', '기초전기전자공학', 3, '화5,6,7(I404)', '백수황', '2'), ('HBHF4369', '기초중국어2', 3, '화2,3,4(E204)', '최향란', '1'), ('HBLD5060', '뉴스와리터러시', 3, '화7,8,9(I407)', '서은아', '1'), ('HBHE4348', '독일어연습2', 3, '화C(E503) 목D(E502)', '박정희', '1'), ('HBHE2022', '독일어회화4', 3, '화1,2,3(E402)', '미정', '1'), ('HBEA0030', '디스플레이공학', 3, '화5,6,7(I505)', '이종환', '1'), ('HBBG2052', '디지털 모델링(SW)', 3, '화9,10,11(D103)', '서동진', '2'), ('HBBG2052', '디지털 모델링(SW)', 3, '화1,2,3(D103)', '서동진', '1'), ('HBIE2181', '디지털드로잉', 3, '화1,2,3(D122)', '송용준', '1'), ('HBIE2181', '디지털드로잉', 3, '화5,6,7(D122)', '송용준', '2'), ('HBIE2181', '디지털드로잉', 3, '화8,9,10(D122)', '송용준', '3'), ('HBJP2161', '디지털마케팅애널리틱스', 3, '화11,12,13(I820)', '김길환', '2'), ('HBJP2161', '디지털마케팅애널리틱스', 3, '화2,3,4(I820)', '김길환', '1'), ('HBJP2161', '디지털마케팅애널리틱스', 3, '화11,12,13(I820)', '김길환', '2'), ('HBJP2161', '디지털마케팅애널리틱스', 3, '화11,12,13(I820)', '김길환', '2'), ('HBJP2161', '디지털마케팅애널리틱스', 3, '화2,3,4(I820)', '김길환', '1'), ('HBJP2161', '디지털마케팅애널리틱스', 3, '화2,3,4(I820)', '김길환', '1'), ('HBJB4380', '디지털설계(CAD)', 3, '화6,7(B307) 화0(Y101)', '김태한,이재영', '1'), ('HBJB4380', '디지털설계(CAD)', 3, '화2,3(B306) 화0(Z101)', '김태한,이재영', '2'), ('HBJB4455', '디지털설계스튜디오II(스마트공 원)(PBL)', 3, '화5,6,7(A102)', '백승준', '1'), ('HBJB4458', '디지털시공구조학및재료학 ...

# %% [markdown]
# ## 9. 완전한 Text2SQL 시스템 (SQL 실행 + 자연어 답변)
#
# **TODO: 답변 생성 프롬프트를 팀 데이터에 맞게 수정하세요**

# %%
def query_database(question: str, db: SQLDatabase) -> str:
    """
    자연어 질문 → SQL 생성 → 실행 → 자연어 답변
    """
    # 1. SQL 생성
    print(f"[1] SQL 생성 중...")
    sql = text_to_sql(question, db)
    print(f"    {sql}\n")

    # 2. SQL 실행
    print(f"[2] SQL 실행 중...")
    try:
        result = db.run(sql)
        print(f"    실행 완료\n")
    except Exception as e:
        return f"SQL 실행 오류: {e}"

    # 3. 자연어 답변 생성
    print(f"[3] 답변 생성 중...")

    # TODO: 시스템 프롬프트를 팀 데이터 도메인에 맞게 수정하세요
    system_prompt = """
    당신은 상명대학교 학사일정을 잘 알고있는 전문가입니다.
    SQL 쿼리 결과를 기반으로 사용자의 질문에 자연스럽게 답변하세요.
    답변은 명확하고 이해하기 쉽고 보기쉽게 작성하세요.
    """

    messages = [
        SystemMessage(content=system_prompt),
        HumanMessage(content=f"""
        질문: {question}

        실행한 SQL:
        {sql}

        쿼리 결과:
        {result}

        위 결과를 바탕으로 질문에 답변해주세요.
        """)
    ]

    response = llm.invoke(messages)
    return response.content

print("✓ 완전한 Text2SQL 시스템 준비 완료")
# Out:
# ✓ 완전한 Text2SQL 시스템 준비 완료

# %%
from IPython.display import Markdown, display

# TODO: 팀 데이터에 맞는 질문을 작성하세요
question = "목요일 5교시부터 시작하는 강의 중에서 전심, 캠스톤 제외하고 뭐가 있는지 알려줘. "

print(f"질문: {question}\n")
print("="*80 + "\n")

answer = query_database(question, db)

print("\n" + "="*80)
print("\n답변:")
display(Markdown(answer))
# Out:
# 질문: 목요일 5교시부터 시작하는 강의 중에서 전심, 캠스톤 제외하고 뭐가 있는지 알려줘.
#
# ================================================================================
#
# [1] SQL 생성 중...
#     SELECT "교과목명", "강의시간(강의실)", "담당교수", "분반"
# FROM "SMU_2026_2"
# WHERE "강의시간(강의실)" LIKE '목5%'
#   AND "교과목명" NOT ILIKE '%전심%'
#   AND "교과목명" NOT ILIKE '%캠스톤%';
#
# [2] SQL 실행 중...
#     실행 완료
#
# [3] 답변 생성 중...
#
# ================================================================================
#
# 답변:
# 목요일 **5교시부터 시작하는 강의** 중에서, **전심 / 캠스톤 제외**하면 아래 과목들이 있습니다.
#
# ### 강의 목록
# - 영화와 AI로 배우는 영미드라마
# - 러시아의역사
# - 입체조형디자인
# - 비주얼리터러시
# - 정보인터랙션디자인기초
# - 모션그래픽스
# - 디자인리포트
# - 혁신디자인스튜디오III
# - 패션커뮤니케이션
# - 기초실내디자인
# - 디지털디자인2
# - 환경도자스튜디오2
# - 산업디자인 조형 워크숍
# - 디지털 공간디자인
# - 디자인과 가구
# - 3D모델링Ⅱ
# - 무대기술
# - 소품디자인(PBL)
# - 사진촬영Ⅱ
# - 비주얼저널리즘(PBL)
# - 창의적아이디어발상
# - 만화애니메이션워크샵Ⅰ
# - 캐릭터연출워크샵
# - 3D컴퓨터그래픽스Ⅰ(SW)
# - 3D컴퓨터그래픽스Ⅲ(SW)
# - 경영전략론
# - AI식재설계및실습
# - 기본간호학및실습2
# - 임상추론2(PBL)
# - 소비자행동
# - 반도체공정(PBL)
# - 데이터베이스
# - 머신러닝
# - 전산모델링및실습
# - 통신네트워크
# - Verilog기반디지털시스템설계(PBL)
# - CPU설계(PBL)
# - 로봇비전(IC-PBL)
# - 사고와표현
# - EnglishforAcademicPurposes
# - 상상속의아이디어
# - 문학과삶의철학
# - 명작속의캐릭터와공감인문학
#
# ### 참고
# 쿼리 결과에는 **캡스톤디자인이 포함된 과목**도 일부 섞여 있습니다.
# 예:
# - 패키지디자인워크숍 (캡스톤디자인)
# - 컬렉션스튜디오Ⅱ(캡스톤디자인)
# - Play스페이스디자인Ⅰ(캡스톤디자인)
# - 네트워크디자인세미나(캡스톤디자인)
# - AR‧VR콘텐츠스튜디오Ⅱ(캡스톤디자인)
# - TV쇼콘텐츠방송무대디자인(캡스톤디자인)
# - AI융합실감콘텐츠프로젝트(캡스톤디자인)
#
# 원하시면 제가 이 목록에서 **캡스톤디자인 과목까지 완전히 제외한 최종 목록**만 다시 정리해드릴게요.

# %% [markdown]
# ## 10. 다양한 질문으로 테스트
#
# **TODO: 최소 5개 이상의 다양한 질문으로 테스트하세요**

# %%
# TODO: 팀 데이터에 맞는 다양한 질문들을 작성하세요
# 기본 조회, JOIN, 집계, 정렬 등 다양한 유형의 질문 포함

questions = [
    "주전공 외 수강제한이 있는 과목만 보여줘",
    "금요일 수업이 있는 과목만 찾아줘",
    "AI모빌리티공학과의 수업 시간표를 표로 정리해줘",
    "E-러닝 교과목만 추려줘",
    "이광재교수님 수업 알려줘"
]

for q in questions:
    print(f"\n{'='*80}")
    print(f"질문: {q}")
    print("="*80 + "\n")

    try:
        answer = query_database(q, db)
        print("\n답변:")
        display(Markdown(answer))
    except Exception as e:
        print(f"오류: {e}")
# Out:
# ================================================================================
# 질문: 주전공 외 수강제한이 있는 과목만 보여줘
# ================================================================================
#
# [1] SQL 생성 중...
#     SELECT *
# FROM "SMU_2026_2"
# WHERE "비고" IS NOT NULL
#   AND "비고" <> 'nan'
#   AND "비고" LIKE '%주전공 외 수강제한%';
#
# [2] SQL 실행 중...
#     실행 완료
#
# [3] 답변 생성 중...
#
# 답변:
# 주전공 외 수강제한이 있는 과목만 추려보면 다음과 같습니다.
# (같은 과목이 분반별로 여러 번 나오는 경우도 있습니다.)
#
# ### 해당 과목 목록
# - 패션CAD
# - 패턴메이킹Ⅱ
# - 패션드레이핑
# - 디자인컨셉&트랜드(PBL)
# - 패션소재기획
# - 한국의상(캡스톤디자인)
# - 특수의상디자인(캡스톤디자인)
# - 특수의복구성(캡스톤디자인)
# - 패션워크샵Ⅱ(캡스톤디자인)
# - 패션비지니스창업설계(캡스톤디자인)
# - 컬렉션스튜디오Ⅱ(캡스톤디자인)
# - 스마트스튜디오Ⅱ(캡스톤디자인)
# - 세라믹쥬얼리디자인(PBL)
# - 조형도자디자인
# - 테이블웨어디자인2
# - 디지털 산업디자인
# - 산업디자인 조형 워크숍
# - 리빙프로덕트디자인Ⅱ
# - 디지털 모델링(SW)
# - 디자인워크숍
# - 디지털 공간디자인
# - 디자인과 가구
# - 어드밴스드프로덕트디자인Ⅱ(캡스톤디자인)
# - 포트폴리오 & 디자인 기획
# - 문화환경디자인(캡스톤디자인)
# - 사용자경험디자인(PBL)
# - Living & Life DesignⅡ(캡스톤디자인)
# - 네트워크디자인세미나(캡스톤디자인)
# - 메타 공간 환경디자인Ⅱ(캡스톤디자인)
# - 서양연극사Ⅱ
# - 희곡분석
# - 드래프팅과모델링
# - 재료와기법(PBL)
# - 무대기술
# - 미술과건축
# - AI TV프로덕션디자인프로세스(PBL)
# - 염색과소재변형(캡스톤디자인)
# - TV쇼콘텐츠방송무대디자인(캡스톤디자인)
# - 프로덕션디자인포트폴리오(캡스톤디자인)
# - 만화애니메이션페인팅
# - 창의적아이디어발상
# - 카툰창작실기
# - 애니메이션스토리텔링
# - 만화·애니메이션교수학습방법
# - AI표현기법워크샵
# - 캐릭터연출워크샵
# - 만화·애니메이션 교육프로그램 개발
# - 졸업작품Ⅱ
# - 포트폴리오
# - 모션그래픽(SW)
# - 게임디자인
# - AI와예술
# - 3D컴퓨터그래픽스Ⅰ(SW)
# - AI디자인방법론
# - AI캐릭터콘텐츠디자인(PBL)
# - 영상콘텐츠(PBL)
# - AI인터랙션디자인(PBL)
# - 3D컴퓨터그래픽스Ⅲ(SW)
# - GUI디자인(PBL)
# - 영상이펙트디자인1
# - XR게임프로젝트(캡스톤디자인)
# - AI융합실감콘텐츠프로젝트(캡스톤디자인)
# - AI미디어콘텐츠포트폴리오(캡스톤디자인)
# - 3D그래픽실무
# - 희곡분석
# - 서양연극사Ⅱ
# - 그린환경식물학및실습
# - 디지털설계(CAD)
# - 공간환경계획설계
# - 도시문화와예술사II
# - 스마트에코빌딩디자인(PBL)
# - 스마트에코도시학
# - 디지털설계스튜디오II(스마트공원)(PBL)
# - 디지털시공구조학및재료학
# - 원격탐사-정보데이터 실습
# - 에코시스템 디자인과 생태공학
# - AI식재설계및실습
# - 디지털설계스튜디오IV(CCS스마트도시계획(캡스톤디자인))
# - 그린스마트데이터솔루션 워크숍(캡스톤디자인)
# - 지속가능발전과그린스마트시티
# - 검도Ⅱ
# - 태권도Ⅱ
# - 스키
# - 골프Ⅰ
# - 테니스Ⅱ
# - 웨이트트레이닝
# - 야외활동
# - 건강교육실습론(PBL)
# - 스노우보드
# - 측정평가
# - 운동처방론(캡스톤디자인)
# - 운동재활Ⅱ
# - 스포츠사회학
# - 스포츠마사지/테이핑
# - 인라인
# - AI스포츠프로젝트관리
# - 식품화학(I)및실험
# - 식품산업과인공지능및실험
# - 식품가공공정학및실험
# - 공학수학Ⅰ(PBL)
# - 공학수학Ⅱ(PBL)
# - 자동제어(PBL)
# - 반도체공정(PBL)
# - 전자공학세미나
# - 컴퓨터구조
# - 고급 C프로그래밍
# - 전자회로및설계
# - 통신시스템설계
# - 지능형시스템개론
# - 전자회로및설계실험
# - 정보전송공학
# - 자료구조설계(SW)
# - 머신러닝
# - 지능제어 임베디드 시스템(PBL)
# - 생명공학실험Ⅰ
# - 창의전공설계(PBL)
# - 공학수학프로그래밍
# - C프로그래밍및프로젝트(PBL)
# - RLC회로설계
# - CMOS트랜지스터(PBL)
# - 인공지능기초
# - Verilog기반디지털시스템설계(PBL)
# - ATmega시스템설계(IC-PBL)
# - RLC회로실험
# - Linux운영체제및시스템프로그래밍(PBL)
# - CPU설계(PBL)
# - 필터증폭회로실험
# - 디스플레이공학
# - 필터증폭회로설계
# - 알고리즘코딩테스트
# - ZynqSoC
# - 전공실무특강
#
# 원하시면 제가 다음 단계로
# 1. **전공별로 묶어서 정리**하거나
# 2. **과목명 + 학년 + 분반 + 교수님까지 표로 정리**해서 보여드릴게요.
# ================================================================================
# 질문: 금요일 수업이 있는 과목만 찾아줘
# ================================================================================
#
# [1] SQL 생성 중...
#     SELECT *
# FROM "SMU_2026_2"
# WHERE "강의시간(강의실)" LIKE '%금%'
# ORDER BY "No";
#
# [2] SQL 실행 중...
#     실행 완료
#
# [3] 답변 생성 중...
#
# 답변:
# 금요일 수업이 있는 과목만 추리면 아래와 같습니다.
#
# ### 금요일 수업 과목 목록
# - **AR‧VR프레이밍디자인**
# - **ATmega시스템설계(IC-PBL)**
# - **기초연극워크숍Ⅱ**
# - **유기화학**
# - **만화애니메이션페인팅**
# - **드래프팅과모델링**
# - **전공체험(텍스타일디자인전공)**
# - **컴퓨터프로그래밍실습Ⅱ(PBL)**
# - **정보인터랙션디자인기초**
# - **패션CAD**
# - **화술Ⅱ**
# - **계산과학이론및실습**
# - **한일관계사**
# - **커뮤니케이션디자인기초**
# - **디지털드로잉**
# - **3D애니메이션Ⅰ**
# - **프로그래밍기초**
# - **현대영어권사회와문화(PBL)**
# - **논리회로설계**
# - **모션그래픽스**
# - **식품제품개발론**
# - **한국의상(캡스톤디자인)**
# - **머신러닝의이해**
# - **AI디자인방법론**
# - **지능형시스템개론**
# - **응용언어학**
# - **전시기획실습1(캡스톤디자인)**
# - **스키**
# - **유통물류관리**
# - **리빙앤컬쳐융합프로젝트Ⅱ(캡스톤디자인)**
# - **창의형캡스톤디자인I**
# - **커뮤니케이션디자인 Ⅱ**
# - **재료와색채디자인**
# - **심화 로봇 기구학 및 설계**
# - **AX·DX 프로젝트Ⅱ(캡스톤디자인)**
# - **AR·VR디자인 랩(PBL)**
# - **제어공학및설계(PBL)**
# - **소프트웨어캡스톤디자인Ⅱ**
# - **공연제작실습Ⅱ(PBL)**
# - **영상이펙트디자인1**
# - **성인간호실습3**
# - **지역사회실습**
# - **현장연계프로젝트(캡스톤디자인)**
# - **글로벌간호**
# - **공간속의빛이야기**
# - **실내공간해부학**
# - **정신간호실습**
# - **간호관리실습**
# - **스노우보드**
# - **만화애니메이션워크샵Ⅰ**
# - **실내건축디자인사**
# - **성인간호실습4**
# - **로봇명사와의만남**
# - **지능형로봇의이해**
# - **스페이스디자인스튜디오Ⅲ(캡스톤디자인)**
# - **AI스포츠프로젝트관리**
# - **혁신디자인스튜디오III**
# - **융합디자인스튜디오III**
# - **교양과인성(영화영상전공)**
# - **교양과인성(디자인학부)**
# - **교양과인성(글로벌금융경영학부)**
# - **교양과인성(전자공학과)**
# - **교양과인성(휴먼지능로봇공학과)**
# - **안전및조직관리사례연구**
# - **조직리더십사례연구**
# - **문화다양성과미디어**
# - **실용한자한문**
# - **영화로읽는러시아·중앙아시아**
# - **생활과경제**
# - **현대사회와공간**
# - **생활속로봇디자인**
# - **에너지와녹색산업**
# - **한국문화입문**
# - **중급일본어**
# - **충남의이해**
# - **인공지능과알고리듬사회**
# - **글로벌위기대응과AI기반지속가능한생태계**
# - **일본어입문**
# - **뉴스영어읽기**
#
# 원하시면 제가 다음 단계로
# **1) 과목명만 깔끔하게 중복 제거해서 정리**하거나,
# **2) 전공별/학년별로 나눠서** 다시 정리해드릴게요.
# ================================================================================
# 질문: AI모빌리티공학과의 수업 시간표를 표로 정리해줘
# ================================================================================
#
# [1] SQL 생성 중...
#     SELECT
#     "학년",
#     "이수구분",
#     "학수번호",
#     "교과목명",
#     "학점",
#     "이론시간",
#     "실습시간",
#     "교양영역",
#     "강의시간(강의실)",
#     "분반",
#     "담당교수",
#     "비고"
# FROM "SMU_2026_2"
# WHERE "교과목명" ILIKE '%AI모빌리티공학과%'
# ORDER BY "학년", "학수번호", "분반";
#
# [2] SQL 실행 중...
#     실행 완료
#
# [3] 답변 생성 중...
#
# 답변:
# AI모빌리티공학과의 수업 시간표는 아래 1개 과목으로 확인됩니다.
#
# | 학년 | 이수구분 | 학수번호 | 교과목명 | 학점 | 이론시간 | 실습시간 | 교양영역 | 강의시간(강의실) | 분반 | 담당교수 | 비고 |
# |---|---|---|---|---:|---:|---:|---|---|---:|---|---|
# | 1 | 1전선 | HBAM0001 | 전공체험(AI모빌리티공학과) | 2 | 2.0 | 0.0 | - | 수8,9,10(I105) | 1 | 강태구 | 주·다·부전공 학생 수강 제한 / 집중이수제(1~10주차, 3시간씩 수업) |
#
# 원하시면 제가 이 내용을 **요일별로 보기 쉽게 다시 정리**해드릴게요.
# ================================================================================
# 질문: E-러닝 교과목만 추려줘
# ================================================================================
#
# [1] SQL 생성 중...
#     SELECT *
# FROM "SMU_2026_2"
# WHERE "비고" ILIKE '%E-러닝%';
#
# [2] SQL 실행 중...
#     실행 완료
#
# [3] 답변 생성 중...
#
# 답변:
# 아래는 **E-러닝 교과목만** 추린 목록입니다.
#
# ### E-러닝 교과목
# | 학수번호 | 교과목명 | 학점 | 담당교수 | 비고 |
# |---|---|---:|---|---|
# | HBLA5004 | AI시대의호모로퀜스(말하는인간) | 3 | 전정미 | 3~4학년만 수강 가능 |
# | HBJP2151 | 경영데이터분석기초 | 3 | 김길환 | 원격수업, e-러닝 |
# | HBLA5027 | 영화로읽는러시아·중앙아시아 | 3 | 이희원 | 3~4학년만 수강 가능 |
# | HBLA5035 | 현대사회와윤리 | 2 | 김현주 | 3~4학년만 수강 가능 |
# | HBLA5041 | 문명속의수학 | 2 | 김신욱 | 3~4학년만 수강 가능 |
# | HBLA5208 | 바이러스와인류역사 | 3 | 이진영 | 3~4학년만 수강 가능 |
# | HBLB5031 | 발명과창업 | 3 | 왕한호 | 3~4학년만 수강 가능 |
# | HBLB5066 | 파이썬빅데이터시각화 | 3 | 이우진, 전준헌 | 3~4학년만 수강 가능 |
# | HBLB5092 | 미래유망직업탐색 | 1 | 김병재 | 3~4학년만 수강 가능 |
# | HBLD5062 | 다문화사회와지속가능한도시공동체 | 3 | 조순정 | 3~4학년만 수강 가능 |
# | HBLF0002 | 상상과창조 | 3 | 김일림 | 3~4학년만 수강 가능 |
# | HBLF0013 | 문화콘텐츠스토리텔링전략 | 3 | 김일림 | 3~4학년만 수강 가능 |
# | HBLF0017 | 문화기술과사회변동 | 3 | 김일림 | 3~4학년만 수강 가능 |
# | HBLF0018 | 문화콘텐츠마케팅전략의수립과집행 | 3 | 김일림 | 3~4학년만 수강 가능 |
# | HBLF0024 | 기업경영과비즈니스전략 | 3 | 김일림 | 3~4학년만 수강 가능 |
# | HBLF0026 | 색채심리와현대생활 | 3 | 김일림 | 3~4학년만 수강 가능 |
# | HBLF0027 | 21세기기업의인재상 | 3 | 김일림 | 3~4학년만 수강 가능 |
# | HBLF7809 | 채움과비움:나이듦의인문학적이해 | 3 | 김일림 | 3~4학년만 수강 가능 |
# | HBLF7811 | 비즈니스모델디자인과린스타트업활동 | 3 | 김일림 | 3~4학년만 수강 가능 |
# | HBLF7818 | 현대미술사와이론 | 3 | 오경은 | 3~4학년만 수강 가능 |
# | HBLF7820 | 외국인학생을위한실용한국어 | 3 | 김일림 | 유학생 전용, E-러닝 |
# | HBLF7843 | 나도콘텐츠크리에이터:AI로배우는창작 | 3 | 김일림 | 3~4학년만 수강 가능 |
# | HBLF7844 | 아이디어를현실로-바이브코딩 | 3 | 김일림 | 3~4학년만 수강 가능 |
# | HBLG1014 | 에너지와녹색산업 | 2 | 이흥주 | 3~4학년만 수강 가능 |
# | HBLJ0001 | CI50융합인재로드맵 | 2 | 손인수 | 2~4학년만 수강 가능 |
# | HBLJ0002 | 마음치유,잃어버린나를찾는길 | 3 | 손인수 | 2~4학년만 수강 가능 |
# | HBLJ0004 | 여행과치유:여행으로행복해지기 | 3 | 손인수 | 2~4학년만 수강 가능 |
# | HBLJ0005 | 게임으로배우는정치 | 3 | 손인수 | 2~4학년만 수강 가능 |
# | HBLJ0006 | 안전관리의이해 | 3 | 손인수 | 2~4학년만 수강 가능 |
# | HBLJ0008 | 인공지능과알고리듬사회 | 3 | 손인수 | 2~4학년만 수강 가능 |
# | HBLJ0009 | 글로벌위기대응과AI기반지속가능한생태계 | 3 | 권기환, 김효정, 손인수 | 2~4학년만 수강 가능 |
# | HBLJ0010 | 디지털기술과AI발전에따른사회서비스의변화 | 3 | 홍영준 | 2~4학년만 수강 가능 |
#
# 원하시면 제가 다음으로
# **1) 학점별로 정리**하거나 **2) 1~2학년 수강 가능 과목만 따로** 추려드릴게요.
# ================================================================================
# 질문: 이광재교수님 수업 알려줘
# ================================================================================
#
# [1] SQL 생성 중...
#     SELECT "학수번호", "교과목명", "학점", "이론시간", "실습시간", "강의시간(강의실)", "분반", "담당교수", "비고"
# FROM "SMU_2026_2"
# WHERE "담당교수" LIKE '%이광재%'
# ORDER BY "교과목명", "분반";
#
# [2] SQL 실행 중...
#     실행 완료
#
# [3] 답변 생성 중...
#
# 답변:
# 이광재 교수님 수업은 다음과 같습니다.
# (쿼리 결과에 동일 과목이 2번씩 나온 항목이 있어 한 번씩만 정리했습니다.)
#
# - **IoT시스템응용**
#   - 학수번호: **HBRO0064**
#   - 학점: **3학점**
#   - 시간: **화 1,2,3**
#   - 강의실: **N203**
#   - 분반: **1**
#
# - **교양과인성(AI모빌리티)**
#   - 학수번호: **HBLG9063**
#   - 학점: **1학점**
#   - 시간: **월 10**
#   - 강의실: **Z101**
#   - 분반: **2**
#
# - **모빌리티입문설계(PBL)**
#   - 학수번호: **HBAM0003**
#   - 학점: **2학점**
#   - 시간: **화 5,6**
#   - 강의실: **C415**
#   - 분반: **1**
#
# - **선형대수**
#   - 학수번호: **HBAM0006**
#   - 학점: **3학점**
#   - 시간: **월 6,7,8**
#   - 강의실: **AB102**
#   - 분반: **1**
#
# - **지능형로봇의이해**
#   - 학수번호: **HBLF7832**
#   - 학점: **2학점**
#   - 시간: **금 7,8**
#   - 강의실: **I105**
#   - 비고: **혁신융합대학사업교과목(텔레프레즌스), 글로벌데이터경영융합전공**
#   - 분반: **1**
#
# - **회로이론 및 실습**
#   - 학수번호: **HBAM0012**
#   - 학점: **3학점**
#   - 시간: **목 1,2,3**
#   - 강의실: **C415**
#   - 분반: **1**
#
# 원하시면 제가
# **“이광재 교수님 수업 중 시간표 형태로 정리”** 하거나
# **“학점 합계까지 계산해서”** 알려드릴게요.

# %% [markdown]
# ## 프로젝트 점검 체크리스트
#
# **완료한 항목을 확인하세요:**
#
# - [ ] CSV 파일 준비 및 데이터 확인 완료
# - [ ] CSV 데이터 탐색 및 통계 분석 완료
# - [ ] Supabase 연결 완료
# - [ ] CSV 데이터 업로드 완료
# - [ ] 직접 작성한 SQL 쿼리 테스트 완료 (최소 3개)
# - [ ] Text2SQL 함수 구현 및 프롬프트 수정 완료
# - [ ] 자연어 질문으로 SQL 생성 테스트 완료
# - [ ] 완전한 Text2SQL 시스템 (답변 생성) 테스트 완료
# - [ ] 최소 5개 이상의 다양한 질문으로 테스트 완료
#
# ---
#
# ## 추가 개선 아이디어
#
# 1. **프롬프트 개선**: SQL 생성 정확도 향상을 위한 예시 추가
# 2. **에러 핸들링**: SQL 오류 발생 시 재시도 로직 구현
# 3. **쿼리 검증**: 생성된 SQL이 안전한지 검증하는 로직 추가
# 4. **결과 포맷팅**: 테이블 형태로 결과 출력
# 5. **쿼리 히스토리**: 실행한 쿼리와 결과를 저장하여 재사용
# 6. **고급 SQL**: 서브쿼리, CTE, 윈도우 함수 활용
