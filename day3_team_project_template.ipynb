# %% [markdown]
# # **3일차 팀 프로젝트: 테이블 데이터 조회 시스템 구축**
#
# ## 프로젝트 목표
# 1. 팀에서 선정한 CSV 테이블 데이터를 Supabase에 적재
# 2. SQL 쿼리로 데이터 조회 테스트
# 3. Text2SQL 시스템 구현 및 테스트
#
# ## 구현 단계
# - 환경 설정 확인
# - CSV 파일 확인 및 탐색
# - Supabase 연결
# - CSV 데이터 업로드
# - SQL 쿼리 테스트
# - Text2SQL 시스템 구현 및 테스트

# %% [markdown]
# ## 0. 환경 변수 설정

# %%
import os
from dotenv import load_dotenv

load_dotenv()

# OpenAI API Key 확인
if os.environ.get("OPENAI_API_KEY"):
    print("✓ OpenAI API Key가 설정되었습니다.")
else:
    print("✗ OpenAI API Key가 없습니다.")

# Supabase 설정 확인
if os.environ.get("SUPABASE_DB_URL"):
    print("✓ Supabase DB URL이 설정되었습니다.")
else:
    print("✗ Supabase DB URL이 필요합니다.")
    print("  .env 파일에 SUPABASE_DB_URL을 추가하세요.")
# Out:
# ✓ OpenAI API Key가 설정되었습니다.
# ✓ Supabase DB URL이 설정되었습니다.

# %% [markdown]
# ## 1. CSV 파일 확인 및 탐색
#
# **TODO: 팀에서 준비한 CSV 파일 경로를 입력하세요**
#
# **중요:** 여러 CSV 파일을 사용하는 경우, 테이블 간 관계(Foreign Key)를 고려하여 업로드 순서를 결정하세요.
# - 부모 테이블 → 자식 테이블 순서로 업로드

# %%
import pandas as pd

# TODO: 팀의 CSV 파일 경로를 입력하세요
# 여러 파일이 있다면 dict 형태로 구성
# 예시:
# csv_files = {
#     "table1": "../datasets/your_table1.csv",
#     "table2": "../datasets/your_table2.csv"
# }

csv_files = {
    "SMU_2026_2": r"C:\Users\USER\Desktop\smu0818\smu-ai-service-bootcamp\rag-system\datasets\2026-2학기_개설학과별_시간표_2026.8.19._기준.csv"
    # 필요한 만큼 추가
}

# CSV 파일 로드 및 확인
dataframes = {}

for table_name, file_path in csv_files.items():
    try:
        df = pd.read_csv(file_path)
        dataframes[table_name] = df

        print("=" * 80)
        print(f"📋 {table_name} 테이블")
        print("=" * 80)
        print(f"\n행 수: {len(df)}")
        print(f"컬럼: {list(df.columns)}")
        print(f"\n첫 5개 행:")
        print(df.head())
        print(f"\n데이터 타입:")
        print(df.dtypes)
        print("\n")

    except Exception as e:
        print(f"✗ {table_name} 로드 실패: {e}\n")

print(f"\n✓ 총 {len(dataframes)}개의 테이블 로드 완료")
# Out:
# ================================================================================
# 📋 SMU_2026_2 테이블
# ================================================================================
#
# 행 수: 1152
# 컬럼: ['No', '학년', '이수구분', '학수번호', '교과목명', '학점', '이론시간', '실습시간', '교양영역', '강의시간(강의실)', '분반', '담당교수', '비고']
#
# 첫 5개 행:
#    No 학년 이수구분      학수번호               교과목명  학점  이론시간  실습시간 교양영역     강의시간(강의실)  \
# 0   1  3  1전선  HBCD0001  취업과창업(글로벌인문학부대학 )   1   1.0   0.0  NaN     토11(Y102)
# 1   1  1  1전선  HBHI0004          글로벌시대의인문학   2   2.0   0.0  NaN    목2,3(E106)
# 2   2  1  1전선  HBHI0004          글로벌시대의인문학   2   2.0   0.0  NaN    목2,3(E503)
# 3   3  1  1전선  HBHI0004          글로벌시대의인문학   2   2.0   0.0  NaN    목2,3(E402)
# 4   1  1  1전선  HBHA1011            한국어학의이해   3   3.0   0.0  NaN  수1,2,3(E502)
#
#   분반     담당교수                               비고
# 0  1      유진현                              NaN
# 1  1  박주은,양동국  글로벌지역학부 1,6 분반만 신청, 이중설강제 선정교과목
# 2  2  윤태희,정의진  글로벌지역학부 2,3 분반만 신청, 이중설강제 선정교과목
# 3  3  박정희,최종술  글로벌지역학부 4,5 분반만 신청, 이중설강제 선정교과목
# 4  1      전정미                              NaN
#
# 데이터 타입:
# No             int64
# 학년               str
# 이수구분             str
# 학수번호             str
# 교과목명             str
# 학점             int64
# 이론시간         float64
# 실습시간         float64
# 교양영역             str
# 강의시간(강의실)        str
# 분반               str
# 담당교수             str
# 비고               str
# dtype: object
#
#
#
# ✓ 총 1개의 테이블 로드 완료

# %% [markdown]
# ## 2. 데이터 탐색 및 통계
#
# **TODO: 팀 데이터에 맞는 탐색 쿼리를 작성하세요**

# %%
# TODO: 각 테이블의 주요 통계를 확인하세요
# 예시:
# - 특정 컬럼의 고유값 개수
# - 카테고리별 데이터 분포
# - 결측치 확인

for table_name, df in dataframes.items():
    print(f"\n{'='*80}")
    print(f"📊 {table_name} 통계")
    print("="*80)

    # 기본 통계
    print("\n[기본 정보]")
    print(df.info())

    # 결측치 확인
    print("\n[결측치]")
    null_counts = df.isnull().sum()
    if null_counts.sum() > 0:
        print(null_counts[null_counts > 0])
    else:
        print("결측치 없음")

    # TODO: 팀 데이터에 맞는 추가 탐색 코드를 작성하세요
    # 예시:
    # print("\n[카테고리 분포]")
    # print(df['YOUR_COLUMN'].value_counts())
# Out:
# ================================================================================
# 📊 SMU_2026_2 통계
# ================================================================================
#
# [기본 정보]
# <class 'pandas.DataFrame'>
# RangeIndex: 1152 entries, 0 to 1151
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   No         1152 non-null   int64
#  1   학년         1152 non-null   str
#  2   이수구분       1152 non-null   str
#  3   학수번호       1152 non-null   str
#  4   교과목명       1152 non-null   str
#  5   학점         1152 non-null   int64
#  6   이론시간       1152 non-null   float64
#  7   실습시간       1152 non-null   float64
#  8   교양영역       150 non-null    str
#  9   강의시간(강의실)  1146 non-null   str
#  10  분반         1146 non-null   str
#  11  담당교수       1146 non-null   str
#  12  비고         533 non-null    str
# dtypes: float64(2), int64(2), str(9)
# memory usage: 230.3 KB
# None
#
# [결측치]
# 교양영역         1002
# 강의시간(강의실)       6
# 분반              6
# 담당교수            6
# 비고            619
# dtype: int64

# %% [markdown]
# ## 3. Supabase PostgreSQL 연결

# %%
from langchain_community.utilities import SQLDatabase

supabase_db_url = os.getenv("SUPABASE_DB_URL")

if not supabase_db_url:
    raise Exception("SUPABASE_DB_URL이 설정되지 않았습니다. .env 파일을 확인하세요.")

print("Supabase PostgreSQL 연결 중...\n")

try:
    # LangChain SQLDatabase로 PostgreSQL 연결
    db = SQLDatabase.from_uri(supabase_db_url)

    print("✓ PostgreSQL 연결 성공!\n")
    print("현재 테이블 목록:")
    tables = db.get_usable_table_names()
    print(tables)

except Exception as e:
    print(f"✗ 연결 실패: {e}")
    raise
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_26816\1442992373.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.utilities import SQLDatabase
# Supabase PostgreSQL 연결 중...
#
# ✓ PostgreSQL 연결 성공!
#
# 현재 테이블 목록:
# ['SMU_2026_2', 'departments', 'office_floors', 'organizations']

# %% [markdown]
# ## 4. Supabase에 CSV 데이터 업로드
#
# ### Supabase 대시보드 (GUI)
# 1. Supabase 대시보드 접속
# 2. Table Editor → Import data from CSV
# 3. **반드시 테이블 관계 순서대로 업로드** (부모 → 자식)
# 4. Foreign Key 에러 발생 시 순서를 재확인

# %% [markdown]
# ## 5. 업로드 확인 및 스키마 탐색

# %%
# 데이터베이스 다시 연결 (업로드 후 스키마 갱신)
db = SQLDatabase.from_uri(supabase_db_url)

print("=== 데이터베이스 스키마 ===")
print(db.table_info)

print("\n" + "="*80 + "\n")

# 각 테이블의 샘플 데이터
for table in db.get_usable_table_names():
    print(f"{table} 테이블 샘플:")
    try:
        result = db.run(f"SELECT * FROM {table} LIMIT 3")
        print(result)
    except Exception as e:
        print(f"조회 실패: {e}")
    print()
# Out:
# === 데이터베이스 스키마 ===
#
# CREATE TABLE "SMU_2026_2" (
# 	"No" BIGINT,
# 	"학년" TEXT,
# 	"이수구분" TEXT,
# 	"학수번호" TEXT,
# 	"교과목명" TEXT,
# 	"학점" BIGINT,
# 	"이론시간" DOUBLE PRECISION,
# 	"실습시간" DOUBLE PRECISION,
# 	"교양영역" TEXT,
# 	"강의시간(강의실)" TEXT,
# 	"분반" TEXT,
# 	"담당교수" TEXT,
# 	"비고" TEXT
# )
#
# /*
# 3 rows from SMU_2026_2 table:
# No	학년	이수구분	학수번호	교과목명	학점	이론시간	실습시간	교양영역	강의시간(강의실)	분반	담당교수	비고
# 1	3	1전선	HBCD0001	취업과창업(글로벌인문학부대학 )	1	1.0	0.0	None	토11(Y102)	1	유진현	nan
# 1	1	1전선	HBHI0004	글로벌시대의인문학	2	2.0	0.0	None	목2,3(E106)	1	박주은,양동국	글로벌지역학부 1,6 분반만 신청, 이중설강제 선정교과목
# 2	1	1전선	HBHI0004	글로벌시대의인문학	2	2.0	0.0	None	목2,3(E503)	2	윤태희,정의진	글로벌지역학부 2,3 분반만 신청, 이중설강제 선정교과목
# */
#
#
# CREATE TABLE departments (
# 	dept_id BIGINT,
# 	dept_name TEXT,
# 	org_id BIGINT,
# 	dept_code TEXT,
# 	phone TEXT,
# 	fax TEXT,
# 	floor_location TEXT,
# 	description TEXT
# )
#
# /*
# 3 rows from departments table:
# dept_id	dept_name	org_id	dept_code	phone	fax	floor_location	description
# 101	홍보담당관	2	D101	041-521-2080	041-521-2089	본관 8층	홍보업무 총괄 및 보도자료 관리
# 102	감사관	2	D102	041-521-2040	041-521-2049	본관 4층	감사업무 총괄 및 청렴윤리 관리
# 103	스마트도시추진과	2	D103	041-521-2205	041-521-2209	본관 7층	스마트도시 정책 및 AI산업 추진
# */
#
#
# CREATE TABLE office_floors (
# 	floor_id BIGINT,
# 	building_name TEXT,
# 	floor_number BIGINT,
# 	floor_name TEXT,
# 	main_departments TEXT,
# 	facilities TEXT,
# 	area_type TEXT
# )
#
# /*
# 3 rows from office_floors table:
# floor_id	building_name	floor_number	floor_name	main_departments	facilities	area_type
# 1	천안시청 본관	1	본관 1층	민원여권과,노인복지과,허가과,복지정책과,장애인복지과,청년정책과	청사카페,민원실,대기공간	민원서비스층
# 2	천안시청 본관	2	본관 2층	미래전략과,일자리경제과,교육청소년과,청소행정과,K-컬처박람회추진과	도솔도서관	행정문화층
# 3	천안시청 본관	3	본관 3층	여성가족과,아동보육과	콜센터,대회의실,천안시정공무원노동조합	복지행정층
# */
#
#
# CREATE TABLE organizations (
# 	org_id BIGINT,
# 	org_name TEXT,
# 	org_type TEXT,
# 	parent_org_id BIGINT,
# 	org_level BIGINT,
# 	org_code TEXT,
# 	description TEXT
# )
#
# /*
# 3 rows from organizations table:
# org_id	org_name	org_type	parent_org_id	org_level	org_code	description
# 1	천안시청	시청	None	1	CA001	천안시 본청
# 2	부시장 직속	직속	1	2	CA002	부시장 직속 부서
# 3	기획조정실	실	1	2	CA003	정책 기획 및 예산 총괄
# */
#
# ================================================================================
#
# SMU_2026_2 테이블 샘플:
# 조회 실패: (psycopg2.errors.UndefinedTable) relation "smu_2026_2" does not exist
# LINE 1: SELECT * FROM SMU_2026_2 LIMIT 3
#                       ^
#
# [SQL: SELECT * FROM SMU_2026_2 LIMIT 3]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#
# departments 테이블 샘플:
# [(101, '홍보담당관', 2, 'D101', '041-521-2080', '041-521-2089', '본관 8층', '홍보업무 총괄 및 보도자료 관리'), (102, '감사관', 2, 'D102', '041-521-2040', '041-521-2049', '본관 4층', '감사업무 총괄 및 청렴윤리 관리'), (103, '스마트도시추진과', 2, 'D103', '041-521-2205', '041-521-2209', '본관 7층', '스마트도시 정책 및 AI산업 추진')]
#
# office_floors 테이블 샘플:
# [(1, '천안시청 본관', 1, '본관 1층', '민원여권과,노인복지과,허가과,복지정책과,장애인복지과,청년정책과', '청사카페,민원실,대기공간', '민원서비스층'), (2, '천안시청 본관', 2, '본관 2층', '미래전략과,일자리경제과,교육청소년과,청소행정과,K-컬처박람회추진과', '도솔도서관', '행정문화층'), (3, '천안시청 본관', 3, '본관 3층', '여성가족과,아동보육과', '콜센터,대회의실,천안시정공무원노동조합', '복지행정층')]
#
# organizations 테이블 샘플:
# [(1, '천안시청', '시청', None, 1, 'CA001', '천안시 본청'), (2, '부시장 직속', '직속', 1, 2, 'CA002', '부시장 직속 부서'), (3, '기획조정실', '실', 1, 2, 'CA003', '정책 기획 및 예산 총괄')]

# %% [markdown]
# ## 6. SQL 쿼리 테스트
#
# **TODO: 팀 데이터에 맞는 SQL 쿼리를 작성하여 테스트하세요**

# %%
# TODO: 조건부 조회 쿼리 작성 (학점이 3 이상인 과목)

query = """
SELECT "교과목명", "이수구분", "학점", "담당교수", "강의시간(강의실)"
FROM "SMU_2026_2"
WHERE "학점" >= 3
LIMIT 10;
"""

print("실행 쿼리:")
print(query)
print("\n결과:")

try:
    result = db.run(query)
    print(result)
except Exception as e:
    print(f"쿼리 실행 오류: {e}")
# Out:
# 실행 쿼리:
#
# SELECT "교과목명", "이수구분", "학점", "담당교수", "강의시간(강의실)"
# FROM "SMU_2026_2"
# WHERE "학점" >= 3
# LIMIT 10;
#
#
# 결과:
# [('한국어학의이해', '1전선', 3, '전정미', '수1,2,3(E502)'), ('한국현대시의이해', '1전선', 3, '김지윤', '수5,6,7(E502)'), ('한국현대소설의이해', '1전선', 3, '김한식', '월5,6,7(E502)'), ('한국고전서사와문화콘텐츠', '1전선', 3, '이희영', '수6,7,8(I110)'), ('한국어어휘교육론', '1전선', 3, '양영하,한정희', '수1,2,3(I109)'), ('AI 시대의 시 감상과 뉴미디어 표현', '1전심', 3, '김지윤', '목3,4,5(C301)'), ('한국어발음교육론', '1전선', 3, '한정희', '화5,6,7(E502)'), ('한국문학과세계문학', '1전선', 3, '김한식', '목1,2,3(I110)'), ('한국어한자교육론', '1전심', 3, '이희영', '목1,2,3(E502)'), ('한국어이해교육론', '1전심', 3, '전정미', '화1,2,3(E502)')]

# %%
# TODO: JOIN 쿼리 작성 (여러 테이블을 사용하는 경우)
# 예시: 두 테이블을 조인하여 데이터 조회

join_query = """
-- TODO: JOIN 쿼리를 작성하세요
-- 예시:
-- SELECT a.column1, b.column2
-- FROM table1 a
-- INNER JOIN table2 b ON a.id = b.foreign_id
-- LIMIT 10;
"""

print("실행 쿼리:")
print(join_query)
print("\n결과:")

try:
    result = db.run(join_query)
    print(result)
except Exception as e:
    print(f"쿼리 실행 오류: {e}")

# %%
# TODO: 집계(Aggregation) 쿼리 작성

aggregation_query = """
SELECT 
    "이수구분", 
    COUNT(*) AS "개설과목수", 
    SUM("학점") AS "총학점"
FROM "SMU_2026_2"
GROUP BY "이수구분"
ORDER BY "개설과목수" DESC;
"""

print("실행 쿼리:")
print(aggregation_query)
print("\n결과:")

try:
    result = db.run(aggregation_query)
    print(result)
except Exception as e:
    print(f"쿼리 실행 오류: {e}")
# Out:
# 실행 쿼리:
#
# SELECT
#     "이수구분",
#     COUNT(*) AS "개설과목수",
#     SUM("학점") AS "총학점"
# FROM "SMU_2026_2"
# GROUP BY "이수구분"
# ORDER BY "개설과목수" DESC;
#
#
# 결과:
# [('1전선', 643, Decimal('1819')), ('1전심', 254, Decimal('707')), ('교선', 183, Decimal('423')), ('교필', 65, Decimal('159')), ('1MD', 4, Decimal('12')), ('일선', 3, Decimal('8'))]

# %% [markdown]
# ## 7. Text2SQL 함수 구현
#
# **TODO: 시스템 프롬프트를 팀 데이터 도메인에 맞게 수정하세요**

# %%
from langchain.chat_models import init_chat_model
from langchain_core.messages import SystemMessage, HumanMessage

llm = init_chat_model("gpt-5.4-mini")

def text_to_sql(question: str, db: SQLDatabase) -> str:
    """
    자연어 질문을 SQL로 변환
    """
    # TODO: 시스템 프롬프트를 팀 데이터에 맞게 수정하세요
    system_prompt = f"""
    당신은 SQL 전문가입니다.
    사용자의 질문을 SQL 쿼리로 변환하세요.

    데이터베이스 스키마:
    {db.table_info}

    규칙:
    - PostgreSQL 문법 사용
    - SELECT 쿼리만 생성 (INSERT, UPDATE, DELETE 금지)
    - SQL 코드만 반환 (설명 불필요)
    - 코드 블록(```) 없이 순수 SQL만 반환
    - 세미콜론(;)으로 끝내기

    사용 가능한 SQL 문법:
    - JOIN (INNER, LEFT, RIGHT, FULL)
    - GROUP BY, HAVING
    - 집계 함수 (COUNT, SUM, AVG, MIN, MAX)
    - 서브쿼리
    - WHERE, ORDER BY, LIMIT
    - CTE (WITH 절)
    - 윈도우 함수
    """

    messages = [
        SystemMessage(content=system_prompt),
        HumanMessage(content=question)
    ]

    response = llm.invoke(messages)
    sql = response.content.strip()

    # 코드 블록 제거
    if sql.startswith("```"):
        lines = sql.split("\n")
        sql = "\n".join(lines[1:-1]) if len(lines) > 2 else sql
        sql = sql.replace("sql", "").replace("```", "").strip()

    return sql

print("✓ Text2SQL 함수 준비 완료")
# Out:
# ✓ Text2SQL 함수 준비 완료

# %% [markdown]
# ## 8. Text2SQL 테스트
#
# **TODO: 팀 데이터에 맞는 자연어 질문으로 테스트하세요**

# %%
# TODO: 팀 데이터에 맞는 질문을 작성하세요
question = "화요일 3학점 수업 알려줘."

print(f"질문: {question}\n")
print("="*80)

# SQL 생성
sql = text_to_sql(question, db)
print(f"\n생성된 SQL:")
print(sql)
print()

# SQL 실행
print("="*80)
print("\n실행 결과:")
try:
    result = db.run(sql)
    print(result)
except Exception as e:
    print(f"실행 오류: {e}")
# Out:
# 질문: 화요일 3학점 수업 알려줘.
#
# ================================================================================
#
# 생성된 SQL:
# SELECT "학수번호", "교과목명", "학점", "강의시간(강의실)", "담당교수"
# FROM "SMU_2026_2"
# WHERE "학점" = 3
#   AND "강의시간(강의실)" LIKE '화%'
# ORDER BY "교과목명";
#
# ================================================================================
#
# 실행 결과:
# [('HBIT0014', '3D 환경 디자인', 3, '화1,2,3(F305)', '김원재'), ('HBIT0005', '3D모델링Ⅱ', 3, '화5,6,7(F305)', '김국토,김원재'), ('HBIT0005', '3D모델링Ⅱ', 3, '화5,6,7(F305)', '김국토,김원재'), ('HBIT0005', '3D모델링Ⅱ', 3, '화5,6,7(F305)', '김국토,김원재'), ('HBIT0021', '3D영상제작Ⅱ', 3, '화1,2,3(F301)', '이상원,조혜정'), ('HBIT0021', '3D영상제작Ⅱ', 3, '화1,2,3(F301)', '이상원,조혜정'), ('HBKI0059', '3D컴퓨터그래픽스Ⅲ(SW)', 3, '화5,6,7(D422)', '이승엽'), ('HBKJ0045', 'AI 콘텐츠기획&제작', 3, '화1,2,3(D412)', '설지형'), ('HBEB0055', 'AI로봇어드벤처디자인', 3, '화6,7(I510) 화0(Z101)', '염기원'), ('HBKI0048', 'AI미디어콘텐츠포트폴리오(캡스 톤디자인)', 3, '화1,2,3(I208)', '은광하'), ('HBKI0048', 'AI미디어콘텐츠포트폴리오(캡스 톤디자인)', 3, '화6,7,8(D423)', '조일현'), ('HBLF7826', 'AI시대의컬처리터러시', 3, '화1,2,3(I210)', '임혜원'), ('HBKI0056', 'AI와예술', 3, '화1,2,3(D421)', '허영'), ('HBKJ0043', 'AI표현기법워크샵', 3, '화8,9,10(D414)', '김서윤'), ('HBMA1022', 'C프로그래밍및프로젝트(PBL)', 3, '화5,6,7(I409)', '김혜윤'), ('HBLA5210', 'EnglishforAcademicPurposes', 3, '화1,2,3(I106)', '방민희'), ('HBLA5210', 'EnglishforAcademicPurposes', 3, '화1,2,3(I104)', '박태숙'), ('HBRO0064', 'IoT시스템응용', 3, '화1,2,3(N203)', '이광재'), ('HBLB5080', 'K-culture를통해보는예술의산업 가치', 3, '화1,2,3(I307)', '강혜승'), ('HBIE2132', 'Shop스페이스디자인Ⅰ(PBL)', 3, '화6,7,8(D327)', '명은정'), ('HBIE2132', 'Shop스페이스디자인Ⅰ(PBL)', 3, '화6,7,8(D322)', '신라영'), ('HBJN2109', 'VerilogHDL과디지털시스템설계', 3, '화1,2,3(C317)', '김선희'), ('HBHE4370', 'ZD독일어', 3, '화6,7,8(E402)', '미정'), ('HBIE3221', '가구와인간공학', 3, '화1,2,3(D327)', '명은정'), ('HBAM0005', '객체지향프로그래밍', 3, '화7,8,9(N203)', '강태구'), ('HBAM0005', '객체지향프로그래밍', 3, '화7,8,9(N203)', '강태구'), ('HBMA1008', '객체지향프로그래밍(PBL)', 3, '화5,6,7(I805)', '김기봉'), ('HBVE0002', '게임엔진2', 3, '화1,2,3(D422)', '공지훈'), ('HBKJ0077', '게임제작과 컨셉아트', 3, '화1,2,3(D409)', '김치훈'), ('HBJP2272', '경영통계Ⅱ', 3, '화5,6,7(I820)', '최성훈'), ('HBJE3032', '경영프로젝트(캡스톤디자인)', 3, '화1,2,3(I105)', '이경희'), ('HBJP2255', '경제성공학', 3, '화1,2,3(I801A)', '서광규'), ('HBJP2255', '경제성공학', 3, '화1,2,3(I801A)', '서광규'), ('HBMA1023', '계산과학이론및실습', 3, '화8,9,10(I404)', '정성균'), ('HBMA1018', '고급 C프로그래밍', 3, '화4(I719) 수1,2(I719)', '박현주'), ('HBSM0010', '고급 R 프로그래밍', 3, '화1,2,3(I805)', '김기봉'), ('HBJO2231', '고성능컴퓨팅(PBL)', 3, '화1,2,3(I107)', '성광제'), ('HBKE0063', '공연기획실습2(캡스톤디자인)', 3, '화5,6(S103) 목11(S103)', '최현주'), ('HBKE0041', '공연예술경영론', 3, '화2,3,4(I109)', '최현주'), ('HBJW0034', '공학수학Ⅱ(PBL)', 3, '화4,5,6(C407B)', '조준희'), ('HBJE4355', '관리회계', 3, '화5,6,7(I111)', '오동일'), ('HBHD4556', '국제사회와일본정치', 3, '화1,2,3(E205)', '양동국'), ('HBOA1031', '그린스마트데이터솔루션 워크숍(캡스톤디자인)', 3, '화5,6,7(B306)', '조미경'), ('HBIE4374', '기초실내디자인', 3, '화8,9,10(D325)', '하숙녕'), ('HBIH4523', '기초연극워크숍Ⅱ', 3, '화2,3(S109) 금9(S109)', '윤기훈'), ('HBEB0030', '기초전기전자공학', 3, '화5,6,7(I404)', '백수황'), ('HBHF4369', '기초중국어2', 3, '화2,3,4(E204)', '최향란'), ('HBLD5060', '뉴스와리터러시', 3, '화7,8,9(I407)', '서은아'), ('HBHE4348', '독일어연습2', 3, '화C(E503) 목D(E502)', '박정희'), ('HBHE2022', '독일어회화4', 3, '화1,2,3(E402)', '미정'), ('HBEA0030', '디스플레이공학', 3, '화5,6,7(I505)', '이종환'), ('HBBG2052', '디지털 모델링(SW)', 3, '화9,10,11(D103)', '서동진'), ('HBBG2052', '디지털 모델링(SW)', 3, '화1,2,3(D103)', '서동진'), ('HBIE2181', '디지털드로잉', 3, '화1,2,3(D122)', '송용준'), ('HBIE2181', '디지털드로잉', 3, '화5,6,7(D122)', '송용준'), ('HBIE2181', '디지털드로잉', 3, '화8,9,10(D122)', '송용준'), ('HBJP2161', '디지털마케팅애널리틱스', 3, '화11,12,13(I820)', '김길환'), ('HBJP2161', '디지털마케팅애널리틱스', 3, '화2,3,4(I820)', '김길환'), ('HBJP2161', '디지털마케팅애널리틱스', 3, '화11,12,13(I820)', '김길환'), ('HBJP2161', '디지털마케팅애널리틱스', 3, '화11,12,13(I820)', '김길환'), ('HBJP2161', '디지털마케팅애널리틱스', 3, '화2,3,4(I820)', '김길환'), ('HBJP2161', '디지털마케팅애널리틱스', 3, '화2,3,4(I820)', '김길환'), ('HBJB4380', '디지털설계(CAD)', 3, '화6,7(B307) 화0(Y101)', '김태한,이재영'), ('HBJB4380', '디지털설계(CAD)', 3, '화2,3(B306) 화0(Z101)', '김태한,이재영'), ('HBJB4455', '디지털설계스튜디오II(스마트공 원)(PBL)', 3, '화5,6,7(A102)', '백승준'), ('HBJB4458', '디지털시공구조학및재료학', 3, '화1,2,3(B307)', '정용조'), ('HBJQ0050', '리눅스보안실습', 3, '화5,6,7(I619)', '서창진'), ('HBJQ0050', '리눅스보안실습', 3, '화5,6,7(I619)', '서창진'), ('HBIF3152', '리빙제품디자인2', 3, '화1,2,3(F201)', '김은호'), ('HBKJ0074', '만화·웹툰그래픽스Ⅱ', 3, '화5,6,7(D414)', '김서윤'), ('HBKJ0109', '만화·웹툰작품창작', 3, '화5,6,7(D412)', '강원구'), ('HBKJ0109', '만화·웹툰작품창작', 3, '화1,2 ...

# %% [markdown]
# ## 9. 완전한 Text2SQL 시스템 (SQL 실행 + 자연어 답변)
#
# **TODO: 답변 생성 프롬프트를 팀 데이터에 맞게 수정하세요**

# %%
def query_database(question: str, db: SQLDatabase) -> str:
    """
    자연어 질문 → SQL 생성 → 실행 → 자연어 답변
    """
    # 1. SQL 생성
    print(f"[1] SQL 생성 중...")
    sql = text_to_sql(question, db)
    print(f"    {sql}\n")

    # 2. SQL 실행
    print(f"[2] SQL 실행 중...")
    try:
        result = db.run(sql)
        print(f"    실행 완료\n")
    except Exception as e:
        return f"SQL 실행 오류: {e}"

    # 3. 자연어 답변 생성
    print(f"[3] 답변 생성 중...")

    # TODO: 시스템 프롬프트를 팀 데이터 도메인에 맞게 수정하세요
    system_prompt = """
    당신은 상명대학교 학사일정을 잘 알고있는 전문가입니다.
    SQL 쿼리 결과를 기반으로 사용자의 질문에 자연스럽게 답변하세요.
    답변은 명확하고 이해하기 쉽고 보기쉽게 작성하세요.
    """

    messages = [
        SystemMessage(content=system_prompt),
        HumanMessage(content=f"""
        질문: {question}

        실행한 SQL:
        {sql}

        쿼리 결과:
        {result}

        위 결과를 바탕으로 질문에 답변해주세요.
        """)
    ]

    response = llm.invoke(messages)
    return response.content

print("✓ 완전한 Text2SQL 시스템 준비 완료")
# Out:
# ✓ 완전한 Text2SQL 시스템 준비 완료

# %%
from IPython.display import Markdown, display

# TODO: 팀 데이터에 맞는 질문을 작성하세요
question = "목요일 5교시부터 시작하는 강의 중에서 전심, 캠스톤 제외하고 뭐가 있는지 알려줘. "

print(f"질문: {question}\n")
print("="*80 + "\n")

answer = query_database(question, db)

print("\n" + "="*80)
print("\n답변:")
display(Markdown(answer))
# Out:
# 질문: 목요일 5교시부터 시작하는 강의 중에서 전심, 캠스톤 제외하고 뭐가 있는지 알려줘.
#
# ================================================================================
#
# [1] SQL 생성 중...
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[30], line 9
#       5
#       6 print(f"질문: {question}\n")
#       7 print("="*80 + "\n")
#       8
# ----> 9 answer = query_database(question, db)
#      10
#      11 print("\n" + "="*80)
#      12 print("\n답변:")
#
# Cell In[14], line 7, in query_database(question, db)
#       3     자연어 질문 → SQL 생성 → 실행 → 자연어 답변
#       4     """
#       5     # 1. SQL 생성
#       6     print(f"[1] SQL 생성 중...")
# ----> 7     sql = text_to_sql(question, db)
#       8     print(f"    {sql}\n")
#       9
#      10     # 2. SQL 실행
#
# Cell In[8], line 40, in text_to_sql(question, db)
#      36         SystemMessage(content=system_prompt),
#      37         HumanMessage(content=question)
#      38     ]
#      39
# ---> 40     response = llm.invoke(messages)
#      41     sql = response.content.strip()
#      42
#      43     # 코드 블록 제거
#
# File c:\Users\USER\Desktop\smu0818\smu-ai-service-bootcamp\rag-system\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File c:\Users\USER\Desktop\smu0818\smu-ai-service-bootcamp\rag-system\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)   1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\USER\Desktop\smu0818\smu-ai-service-bootcamp\rag-system\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File c:\Users\USER\Desktop\smu0818\smu-ai-service-bootcamp\rag-system\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\USER\Desktop\smu0818\smu-ai-service-bootcamp\rag-system\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1738, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1736     _handle_openai_bad_request(e)
#    1737 except openai.APIError as e:
# -> 1738     _handle_openai_api_error(e)
#    1739 except Exception as e:
#    1740     if raw_response is not None and hasattr(raw_response, "http_response"):
#
# File c:\Users\USER\Desktop\smu0818\smu-ai-service-bootcamp\rag-system\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1733, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1726         return _construct_lc_result_from_responses_api(
#    1727             response,
#    1728             schema=original_schema_obj,
#    1729             metadata=generation_info,
#    1730             output_version=self.output_version,
#    1731         )
#    1732     else:
# -> 1733         raw_response = self.client.with_raw_response.create(**payload)
#    1734         response = raw_response.parse()
#    1735 except openai.BadRequestError as e:
#
# File c:\Users\USER\Desktop\smu0818\smu-ai-service-bootcamp\rag-system\.venv\Lib\site-packages\openai\_legacy_response.py:367, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     363 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     365 kwargs["extra_headers"] = extra_headers
# --> 367 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File c:\Users\USER\Desktop\smu0818\smu-ai-service-bootcamp\rag-system\.venv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File c:\Users\USER\Desktop\smu0818\smu-ai-service-bootcamp\rag-system\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1281, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1232 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1233 def create(
#    1234     self,
#    (...)   1278     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1279 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1280     validate_response_format(response_format)
# -> 1281     return self._post(
#    1282         "/chat/completions",
#    1283         body=maybe_transform(
#    1284             {
#    1285                 "messages": messages,
#    1286                 "model": model,
#    1287                 "audio": audio,
#    1288                 "frequency_penalty": frequency_penalty,
#    1289                 "function_call": function_call,
#    1290                 "functions": functions,
#    1291                 "logit_bias": logit_bias,
#    1292                 "logprobs": logprobs,
#    1293                 "max_completion_tokens": max_completion_tokens,
#    1294                 "max_tokens": max_tokens,
#    1295                 "metadata": metadata,
#    1296                 "modalities": modalities,
#    1297                 "moderation": moderation,
#    1298                 "n": n,
#    1299                 "parallel_tool_calls": parallel_tool_calls,
#    1300                 "prediction": prediction,
#    1301                 "presence_penalty": presence_penalty,
#    1302                 "prompt_cache_key": prompt_cache_key,
#    1303                 "prompt_cache_options": prompt_cache_options,
#    1304                 "prompt_cache_retention": prompt_cache_retention,
#    1305                 "reasoning_effort": reasoning_effort,
#    1306                 "response_format": response_format,
#    1307                 "safety_identifier": safety_identifier,
#    1308                 "seed": seed,
#    1309                 "service_tier": service_tier,
#    1310                 "stop": stop,
#    1311                 "store": store,
#    1312                 "stream": stream,
#    1313                 "stream_options": stream_options,
#    1314                 "temperature": temperature,
#    1315                 "tool_choice": tool_choice,
#    1316                 "tools": tools,
#    1317                 "top_logprobs": top_logprobs,
#    1318                 "top_p": top_p,
#    1319                 "user": user,
#    1320                 "verbosity": verbosity,
#    1321                 "web_search_options": web_search_options,
#    1322             },
#    1323             completion_create_params.CompletionCreateParamsStreaming
#    1324             if stream
#    1325             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1326         ),
#    1327         options=make_request_options(
#    1328             extra_headers=extra_headers,
#    1329             extra_query=extra_query,
#    1330             extra_body=extra_body,
#    1331             timeout=timeout,
#    1332             security={"bearer_auth": True},
#    1333         ),
#    1334         cast_to=ChatCompletion,
#    1335         stream=stream or False,
#    1336         stream_cls=Stream[ChatCompletionChunk],
#    1337     )
#
# File c:\Users\USER\Desktop\smu0818\smu-ai-service-bootcamp\rag-system\.venv\Lib\site-packages\openai\_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\USER\Desktop\smu0818\smu-ai-service-bootcamp\rag-system\.venv\Lib\site-packages\openai\_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You have no credits remaining. Add credits to continue using the API at https://platform.openai.com/settings/organization/billing/.', 'type': 'insufficient_quota', 'param': None, 'code': 'credit_balance_exhausted'}}

# %% [markdown]
# ## 10. 다양한 질문으로 테스트
#
# **TODO: 최소 5개 이상의 다양한 질문으로 테스트하세요**

# %%
# TODO: 팀 데이터에 맞는 다양한 질문들을 작성하세요
# 기본 조회, JOIN, 집계, 정렬 등 다양한 유형의 질문 포함

questions = [
    "YOUR_QUESTION_1_HERE",
    "YOUR_QUESTION_2_HERE",
    "YOUR_QUESTION_3_HERE",
    "YOUR_QUESTION_4_HERE",
    "YOUR_QUESTION_5_HERE"
]

for q in questions:
    print(f"\n{'='*80}")
    print(f"질문: {q}")
    print("="*80 + "\n")

    try:
        answer = query_database(q, db)
        print("\n답변:")
        display(Markdown(answer))
    except Exception as e:
        print(f"오류: {e}")

# %% [markdown]
# ## 프로젝트 점검 체크리스트
#
# **완료한 항목을 확인하세요:**
#
# - [ ] CSV 파일 준비 및 데이터 확인 완료
# - [ ] CSV 데이터 탐색 및 통계 분석 완료
# - [ ] Supabase 연결 완료
# - [ ] CSV 데이터 업로드 완료
# - [ ] 직접 작성한 SQL 쿼리 테스트 완료 (최소 3개)
# - [ ] Text2SQL 함수 구현 및 프롬프트 수정 완료
# - [ ] 자연어 질문으로 SQL 생성 테스트 완료
# - [ ] 완전한 Text2SQL 시스템 (답변 생성) 테스트 완료
# - [ ] 최소 5개 이상의 다양한 질문으로 테스트 완료
#
# ---
#
# ## 추가 개선 아이디어
#
# 1. **프롬프트 개선**: SQL 생성 정확도 향상을 위한 예시 추가
# 2. **에러 핸들링**: SQL 오류 발생 시 재시도 로직 구현
# 3. **쿼리 검증**: 생성된 SQL이 안전한지 검증하는 로직 추가
# 4. **결과 포맷팅**: 테이블 형태로 결과 출력
# 5. **쿼리 히스토리**: 실행한 쿼리와 결과를 저장하여 재사용
# 6. **고급 SQL**: 서브쿼리, CTE, 윈도우 함수 활용
